# %% [markdown]
# ## What is pandas?
# ### Working with pandas
# *Curtis Miller*
#
# In this notebook we see a preview of pandas `Series` and `DataFrame`s.
#
# We load in a data set from the hard drive and compare the NumPy object to a pandas object.

# %%
import numpy as np
import pandas as pd

# %%
schema = np.dtype([('sepal_length', np.float16),    # Need to define a custom dtype to read CSV of mixed data type
                   ('sepal_width',  np.float16),
                   ('petal_length', np.float16),
                   ('petal_width',  np.float16),
                   ('species',      '<U16')])

# %%
np_data = np.loadtxt("iris.csv", skiprows=1, dtype=schema, delimiter=',')

# %%
np_data
# Out:
# array([( 5.1015625 ,  3.5       ,  1.40039062,  0.19995117, 'setosa'),
#        ( 4.8984375 ,  3.        ,  1.40039062,  0.19995117, 'setosa'),
#        ( 4.69921875,  3.19921875,  1.29980469,  0.19995117, 'setosa'),
#        ( 4.6015625 ,  3.09960938,  1.5       ,  0.19995117, 'setosa'),
#        ( 5.        ,  3.59960938,  1.40039062,  0.19995117, 'setosa'),
#        ( 5.3984375 ,  3.90039062,  1.70019531,  0.39990234, 'setosa'),
#        ( 4.6015625 ,  3.40039062,  1.40039062,  0.30004883, 'setosa'),
#        ( 5.        ,  3.40039062,  1.5       ,  0.19995117, 'setosa'),
#        ( 4.3984375 ,  2.90039062,  1.40039062,  0.19995117, 'setosa'),
#        ( 4.8984375 ,  3.09960938,  1.5       ,  0.09997559, 'setosa'),
#        ( 5.3984375 ,  3.69921875,  1.5       ,  0.19995117, 'setosa'),
#        ( 4.80078125,  3.40039062,  1.59960938,  0.19995117, 'setosa'),
#        ( 4.80078125,  3.        ,  1.40039062,  0.09997559, 'setosa'),
#        ( 4.30078125,  3.        ,  1.09960938,  0.09997559, 'setosa'),
#        ( 5.80078125,  4.        ,  1.20019531,  0.19995117, 'setosa'),
#        ( 5.69921875,  4.3984375 ,  1.5       ,  0.39990234, 'setosa'),
#        ( 5.3984375 ,  3.90039062,  1.29980469,  0.39990234, 'setosa'),
#        ( 5.1015625 ,  3.5       ,  1.40039062,  0.30004883, 'setosa'),
#        ( 5.69921875,  3.80078125,  1.70019531,  0.30004883, 'setosa'),
#        ( 5.1015625 ,  3.80078125,  1.5       ,  0.30004883, 'setosa'),
#        ( 5.3984375 ,  3.40039062,  1.70019531,  0.19995117, 'setosa'),
#        ( 5.1015625 ,  3.69921875,  1.5       ,  0.39990234, 'setosa'),
#        ( 4.6015625 ,  3.59960938,  1.        ,  0.19995117, 'setosa'),
#        ( 5.1015625 ,  3.30078125,  1.70019531,  0.5       , 'setosa'),
#        ( 4.80078125,  3.40039062,  1.90039062,  0.19995117, 'setosa'),
#        ( 5.        ,  3.        ,  1.59960938,  0.19995117, 'setosa'),
#        ( 5.        ,  3.40039062,  1.59960938,  0.39990234, 'setosa'),
#        ( 5.19921875,  3.5       ,  1.5       ,  0.19995117, 'setosa'),
#        ( 5.19921875,  3.40039062,  1.40039062,  0.19995117, 'setosa'),
#        ( 4.69921875,  3.19921875,  1.59960938,  0.19995117, 'setosa'),
#        ( 4.80078125,  3.09960938,  1.59960938,  0.19995117, 'setosa'),
#        ( 5.3984375 ,  3.40039062,  1.5       ,  0.39990234, 'setosa'),
#        ( 5.19921875,  4.1015625 ,  1.5       ,  0.09997559, 'setosa'),
#        ( 5.5       ,  4.19921875,  1.40039062,  0.19995117, 'setosa'),
#        ( 4.8984375 ,  3.09960938,  1.5       ,  0.09997559, 'setosa'),
#        ( 5.        ,  3.19921875,  1.20019531,  0.19995117, 'setosa'),
#        ( 5.5       ,  3.5       ,  1.29980469,  0.19995117, 'setosa'),
#        ( 4.8984375 ,  3.09960938,  1.5       ,  0.09997559, 'setosa'),
#        ( 4.3984375 ,  3.        ,  1.29980469,  0.19995117, 'setosa'),
#        ( 5.1015625 ,  3.40039062,  1.5       ,  0.19995117, 'setosa'),
#        ( 5.        ,  3.5       ,  1.29980469,  0.30004883, 'setosa'),
#        ( 4.5       ,  2.30078125,  1.29980469,  0.30004883, 'setosa'),
#        ( 4.3984375 ,  3.19921875,  1.29980469,  0.19995117, 'setosa'),
#        ( 5.        ,  3.5       ,  1.59960938,  0.60009766, 'setosa'),
#        ( 5.1015625 ,  3.80078125,  1.90039062,  0.39990234, 'setosa'),
#        ( 4.80078125,  3.        ,  1.40039062,  0.30004883, 'setosa'),
#        ( 5.1015625 ,  3.80078125,  1.59960938,  0.19995117, 'setosa'),
#        ( 4.6015625 ,  3.19921875,  1.40039062,  0.19995117, 'setosa'),
#        ( 5.30078125,  3.69921875,  1.5       ,  0.19995117, 'setosa'),
#        ( 5.        ,  3.30078125,  1.40039062,  0.19995117, 'setosa'),
#        ( 7.        ,  3.19921875,  4.69921875,  1.40039062, 'versicolor'),
#        ( 6.3984375 ,  3.19921875,  4.5       ,  1.5       , 'versicolor'),
#        ( 6.8984375 ,  3.09960938,  4.8984375 ,  1.5       , 'versicolor'),
#        ( 5.5       ,  2.30078125,  4.        ,  1.29980469, 'versicolor'),
#        ( 6.5       ,  2.80078125,  4.6015625 ,  1.5       , 'versicolor'),
#        ( 5.69921875,  2.80078125,  4.5       ,  1.29980469, 'versicolor'),
#        ( 6.30078125,  3.30078125,  4.69921875,  1.59960938, 'versicolor'),
#        ( 4.8984375 ,  2.40039062,  3.30078125,  1.        , 'versicolor'),
#        ( 6.6015625 ,  2.90039062,  4.6015625 ,  1.29980469, 'versicolor'),
#        ( 5.19921875,  2.69921875,  3.90039062,  1.40039062, 'versicolor'),
#        ( 5.        ,  2.        ,  3.5       ,  1.        , 'versicolor'),
#        ( 5.8984375 ,  3.        ,  4.19921875,  1.5       , 'versicolor'),
#        ( 6.        ,  2.19921875,  4.        ,  1.        , 'versicolor'),
#        ( 6.1015625 ,  2.90039062,  4.69921875,  1.40039062, 'versicolor'),
#        ( 5.6015625 ,  2.90039062,  3.59960938,  1.29980469, 'versicolor'),
#        ( 6.69921875,  3.09960938,  4.3984375 ,  1.40039062, 'versicolor'),
#        ( 5.6015625 ,  3.        ,  4.5       ,  1.5       , 'versicolor'),
#        ( 5.80078125,  2.69921875,  4.1015625 ,  1.        , 'versicolor'),
#        ( 6.19921875,  2.19921875,  4.5       ,  1.5       , 'versicolor'),
#        ( 5.6015625 ,  2.5       ,  3.90039062,  1.09960938, 'versicolor'),
#        ( 5.8984375 ,  3.19921875,  4.80078125,  1.79980469, 'versicolor'),
#        ( 6.1015625 ,  2.80078125,  4.        ,  1.29980469, 'versicolor'),
#        ( 6.30078125,  2.5       ,  4.8984375 ,  1.5       , 'versicolor'),
#        ( 6.1015625 ,  2.80078125,  4.69921875,  1.20019531, 'versicolor'),
#        ( 6.3984375 ,  2.90039062,  4.30078125,  1.29980469, 'versicolor'),
#        ( 6.6015625 ,  3.        ,  4.3984375 ,  1.40039062, 'versicolor'),
#        ( 6.80078125,  2.80078125,  4.80078125,  1.40039062, 'versicolor'),
#        ( 6.69921875,  3.        ,  5.        ,  1.70019531, 'versicolor'),
#        ( 6.        ,  2.90039062,  4.5       ,  1.5       , 'versicolor'),
#        ( 5.69921875,  2.59960938,  3.5       ,  1.        , 'versicolor'),
#        ( 5.5       ,  2.40039062,  3.80078125,  1.09960938, 'versicolor'),
#        ( 5.5       ,  2.40039062,  3.69921875,  1.        , 'versicolor'),
#        ( 5.80078125,  2.69921875,  3.90039062,  1.20019531, 'versicolor'),
#        ( 6.        ,  2.69921875,  5.1015625 ,  1.59960938, 'versicolor'),
#        ( 5.3984375 ,  3.        ,  4.5       ,  1.5       , 'versicolor'),
#        ( 6.        ,  3.40039062,  4.5       ,  1.59960938, 'versicolor'),
#        ( 6.69921875,  3.09960938,  4.69921875,  1.5       , 'versicolor'),
#        ( 6.30078125,  2.30078125,  4.3984375 ,  1.29980469, 'versicolor'),
#        ( 5.6015625 ,  3.        ,  4.1015625 ,  1.29980469, 'versicolor'),
#        ( 5.5       ,  2.5       ,  4.        ,  1.29980469, 'versicolor'),
#        ( 5.5       ,  2.59960938,  4.3984375 ,  1.20019531, 'versicolor'),
#        ( 6.1015625 ,  3.        ,  4.6015625 ,  1.40039062, 'versicolor'),
#        ( 5.80078125,  2.59960938,  4.        ,  1.20019531, 'versicolor'),
#        ( 5.        ,  2.30078125,  3.30078125,  1.        , 'versicolor'),
#        ( 5.6015625 ,  2.69921875,  4.19921875,  1.29980469, 'versicolor'),
#        ( 5.69921875,  3.        ,  4.19921875,  1.20019531, 'versicolor'),
#        ( 5.69921875,  2.90039062,  4.19921875,  1.29980469, 'versicolor'),
#        ( 6.19921875,  2.90039062,  4.30078125,  1.29980469, 'versicolor'),
#        ( 5.1015625 ,  2.5       ,  3.        ,  1.09960938, 'versicolor'),
#        ( 5.69921875,  2.80078125,  4.1015625 ,  1.29980469, 'versicolor'),
#        ( 6.30078125,  3.30078125,  6.        ,  2.5       , 'virginica'),
#        ( 5.80078125,  2.69921875,  5.1015625 ,  1.90039062, 'virginica'),
#        ( 7.1015625 ,  3.        ,  5.8984375 ,  2.09960938, 'virginica'),
#        ( 6.30078125,  2.90039062,  5.6015625 ,  1.79980469, 'virginica'),
#        ( 6.5       ,  3.        ,  5.80078125,  2.19921875, 'virginica'),
#        ( 7.6015625 ,  3.        ,  6.6015625 ,  2.09960938, 'virginica'),
#        ( 4.8984375 ,  2.5       ,  4.5       ,  1.70019531, 'virginica'),
#        ( 7.30078125,  2.90039062,  6.30078125,  1.79980469, 'virginica'),
#        ( 6.69921875,  2.5       ,  5.80078125,  1.79980469, 'virginica'),
#        ( 7.19921875,  3.59960938,  6.1015625 ,  2.5       , 'virginica'),
#        ( 6.5       ,  3.19921875,  5.1015625 ,  2.        , 'virginica'),
#        ( 6.3984375 ,  2.69921875,  5.30078125,  1.90039062, 'virginica'),
#        ( 6.80078125,  3.        ,  5.5       ,  2.09960938, 'virginica'),
#        ( 5.69921875,  2.5       ,  5.        ,  2.        , 'virginica'),
#        ( 5.80078125,  2.80078125,  5.1015625 ,  2.40039062, 'virginica'),
#        ( 6.3984375 ,  3.19921875,  5.30078125,  2.30078125, 'virginica'),
#        ( 6.5       ,  3.        ,  5.5       ,  1.79980469, 'virginica'),
#        ( 7.69921875,  3.80078125,  6.69921875,  2.19921875, 'virginica'),
#        ( 7.69921875,  2.59960938,  6.8984375 ,  2.30078125, 'virginica'),
#        ( 6.        ,  2.19921875,  5.        ,  1.5       , 'virginica'),
#        ( 6.8984375 ,  3.19921875,  5.69921875,  2.30078125, 'virginica'),
#        ( 5.6015625 ,  2.80078125,  4.8984375 ,  2.        , 'virginica'),
#        ( 7.69921875,  2.80078125,  6.69921875,  2.        , 'virginica'),
#        ( 6.30078125,  2.69921875,  4.8984375 ,  1.79980469, 'virginica'),
#        ( 6.69921875,  3.30078125,  5.69921875,  2.09960938, 'virginica'),
#        ( 7.19921875,  3.19921875,  6.        ,  1.79980469, 'virginica'),
#        ( 6.19921875,  2.80078125,  4.80078125,  1.79980469, 'virginica'),
#        ( 6.1015625 ,  3.        ,  4.8984375 ,  1.79980469, 'virginica'),
#        ( 6.3984375 ,  2.80078125,  5.6015625 ,  2.09960938, 'virginica'),
#        ( 7.19921875,  3.        ,  5.80078125,  1.59960938, 'virginica'),
#        ( 7.3984375 ,  2.80078125,  6.1015625 ,  1.90039062, 'virginica'),
#        ( 7.8984375 ,  3.80078125,  6.3984375 ,  2.        , 'virginica'),
#        ( 6.3984375 ,  2.80078125,  5.6015625 ,  2.19921875, 'virginica'),
#        ( 6.30078125,  2.80078125,  5.1015625 ,  1.5       , 'virginica'),
#        ( 6.1015625 ,  2.59960938,  5.6015625 ,  1.40039062, 'virginica'),
#        ( 7.69921875,  3.        ,  6.1015625 ,  2.30078125, 'virginica'),
#        ( 6.30078125,  3.40039062,  5.6015625 ,  2.40039062, 'virginica'),
#        ( 6.3984375 ,  3.09960938,  5.5       ,  1.79980469, 'virginica'),
#        ( 6.        ,  3.        ,  4.80078125,  1.79980469, 'virginica'),
#        ( 6.8984375 ,  3.09960938,  5.3984375 ,  2.09960938, 'virginica'),
#        ( 6.69921875,  3.09960938,  5.6015625 ,  2.40039062, 'virginica'),
#        ( 6.8984375 ,  3.09960938,  5.1015625 ,  2.30078125, 'virginica'),
#        ( 5.80078125,  2.69921875,  5.1015625 ,  1.90039062, 'virginica'),
#        ( 6.80078125,  3.19921875,  5.8984375 ,  2.30078125, 'virginica'),
#        ( 6.69921875,  3.30078125,  5.69921875,  2.5       , 'virginica'),
#        ( 6.69921875,  3.        ,  5.19921875,  2.30078125, 'virginica'),
#        ( 6.30078125,  2.5       ,  5.        ,  1.90039062, 'virginica'),
#        ( 6.5       ,  3.        ,  5.19921875,  2.        , 'virginica'),
#        ( 6.19921875,  3.40039062,  5.3984375 ,  2.30078125, 'virginica'),
#        ( 5.8984375 ,  3.        ,  5.1015625 ,  1.79980469, 'virginica')],
#       dtype=[('sepal_length', '<f2'), ('sepal_width', '<f2'), ('petal_length', '<f2'), ('petal_width', '<f2'), ('species', '<U16')])

# %%
type(np_data)
# Out:
# numpy.ndarray

# %%
np_data[:5]    # Slicing operations
# Out:
# array([( 5.1015625 ,  3.5       ,  1.40039062,  0.19995117, 'setosa'),
#        ( 4.8984375 ,  3.        ,  1.40039062,  0.19995117, 'setosa'),
#        ( 4.69921875,  3.19921875,  1.29980469,  0.19995117, 'setosa'),
#        ( 4.6015625 ,  3.09960938,  1.5       ,  0.19995117, 'setosa'),
#        ( 5.        ,  3.59960938,  1.40039062,  0.19995117, 'setosa')],
#       dtype=[('sepal_length', '<f2'), ('sepal_width', '<f2'), ('petal_length', '<f2'), ('petal_width', '<f2'), ('species', '<U16')])

# %%
np_data[:5]['sepal_length']
# Out:
# array([ 5.1015625 ,  4.8984375 ,  4.69921875,  4.6015625 ,  5.        ], dtype=float16)

# %%
np_data[:5][['petal_length', 'species']]
# Out:
# array([( 1.40039062, 'setosa'), ( 1.40039062, 'setosa'),
#        ( 1.29980469, 'setosa'), ( 1.5       , 'setosa'),
#        ( 1.40039062, 'setosa')],
#       dtype=[('petal_length', '<f2'), ('species', '<U16')])

# %% [markdown]
# But there is a better way, with pandas.

# %%
pd_data = pd.read_csv("iris.csv")

# %%
pd_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 6             4.6          3.4           1.4          0.3     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# 9             4.9          3.1           1.5          0.1     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 11            4.8          3.4           1.6          0.2     setosa
# 12            4.8          3.0           1.4          0.1     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# 16            5.4          3.9           1.3          0.4     setosa
# 17            5.1          3.5           1.4          0.3     setosa
# 18            5.7          3.8           1.7          0.3     setosa
# 19            5.1          3.8           1.5          0.3     setosa
# 20            5.4          3.4           1.7          0.2     setosa
# 21            5.1          3.7           1.5          0.4     setosa
# 22            4.6          3.6           1.0          0.2     setosa
# 23            5.1          3.3           1.7          0.5     setosa
# 24            4.8          3.4           1.9          0.2     setosa
# 25            5.0          3.0           1.6          0.2     setosa
# 26            5.0          3.4           1.6          0.4     setosa
# 27            5.2          3.5           1.5          0.2     setosa
# 28            5.2          3.4           1.4          0.2     setosa
# 29            4.7          3.2           1.6          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 120           6.9          3.2           5.7          2.3  virginica
# 121           5.6          2.8           4.9          2.0  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 123           6.3          2.7           4.9          1.8  virginica
# 124           6.7          3.3           5.7          2.1  virginica
# 125           7.2          3.2           6.0          1.8  virginica
# 126           6.2          2.8           4.8          1.8  virginica
# 127           6.1          3.0           4.9          1.8  virginica
# 128           6.4          2.8           5.6          2.1  virginica
# 129           7.2          3.0           5.8          1.6  virginica
# 130           7.4          2.8           6.1          1.9  virginica
# 131           7.9          3.8           6.4          2.0  virginica
# 132           6.4          2.8           5.6          2.2  virginica
# 133           6.3          2.8           5.1          1.5  virginica
# 134           6.1          2.6           5.6          1.4  virginica
# 135           7.7          3.0           6.1          2.3  virginica
# 136           6.3          3.4           5.6          2.4  virginica
# 137           6.4          3.1           5.5          1.8  virginica
# 138           6.0          3.0           4.8          1.8  virginica
# 139           6.9          3.1           5.4          2.1  virginica
# 140           6.7          3.1           5.6          2.4  virginica
# 141           6.9          3.1           5.1          2.3  virginica
# 142           5.8          2.7           5.1          1.9  virginica
# 143           6.8          3.2           5.9          2.3  virginica
# 144           6.7          3.3           5.7          2.5  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(pd_data)
# Out:
# pandas.core.frame.DataFrame

# %%
pd_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
pd_data.head().sepal_length
# Out:
# 0    5.1
# 1    4.9
# 2    4.7
# 3    4.6
# 4    5.0
# Name: sepal_length, dtype: float64

# %%
pd_data.head().loc[:, ['petal_length', 'species']]
# Out:
#    petal_length species
# 0           1.4  setosa
# 1           1.4  setosa
# 2           1.3  setosa
# 3           1.5  setosa
# 4           1.4  setosa

# %%
type(pd_data.sepal_length)

# %% [markdown]
# At its core, though, pandas is built on top of NumPy.

# %%
pd_data.values

# %%
np_pd_data = pd.DataFrame(np_data)    # Converting to a DataFrame
np_pd_data
